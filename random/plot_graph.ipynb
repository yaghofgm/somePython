# %%
import matplotlib.pyplot as plt
import numpy as np

def f(t):
    return (-48*t)*np.exp(-2*t)
x=np.linspace(0,0.1,100)
y=f(x)
plt.plot(x,y)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def f(t):
    return (-48*t)*np.exp(-2*t)
x=np.linspace(0,0.10,100)
y=f(x)
plt.plot(x,y)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def f(t):
    return (-48*t)*np.exp(-2*t)
x=np.linspace(0,1,100)
y=f(x)
plt.plot(x,y)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def f(t):
    return (-48*t)*np.exp(-2*t)
x=np.linspace(0,10,100)
y=f(x)
plt.plot(x,y)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def f(t):
    return (-48*t)*np.exp(-2*t)
x=np.linspace(0,10,1000)
y=f(x)
plt.plot(x,y)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def f(t):
    return (-48*t)*np.exp(-2*t)
x=np.linspace(0,6,1000)
y=f(x)
plt.plot(x,y)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def f1(t):
    return (-48*t)*np.exp(-2*t)

x=np.linspace(0,6,1000)
y1=f1(x)
def f2(t):
    return 6*(2*t-1)*np.exp(-2*t)
y2=f2(x)
plt.plot(x,y1)
plt.plot(x,y2)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def f1(t):
    return np.exp(-500*t)*(-18*np.cos(866*t)-31.2*np.sn(866*t))

x=np.linspace(0,6,1000)
y1=f1(x)
# def f2(t):
#     return 6*(2*t-1)*np.exp(-2*t)
# y2=f2(x)
plt.plot(x,y1)
# plt.plot(x,y2)
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /home/yagho/python/random/plot_graph.py:8
#       5     return np.exp(-500*t)*(-18*np.cos(866*t)-31.2*np.sn(866*t))
#       7 x=np.linspace(0,6,1000)
# ----> 8 y1=f1(x)
#       9 # def f2(t):
#      10 #     return 6*(2*t-1)*np.exp(-2*t)
#      11 # y2=f2(x)
#      12 plt.plot(x,y1)
#
# File /home/yagho/python/random/plot_graph.py:5
#       4 def f1(t):
# ----> 5     return np.exp(-500*t)*(-18*np.cos(866*t)-31.2*np.sn(866*t))
#
# File ~/.local/lib/python3.10/site-packages/numpy/__init__.py:414, in __getattr__(attr)
#     411     import numpy.char as char
#     412     return char.chararray
# --> 414 raise AttributeError("module {!r} has no attribute "
#     415                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'sn'

# %%
import matplotlib.pyplot as plt
import numpy as np

def f1(t):
    return np.exp(-500*t)*(-18*np.cos(866*t)-31.2*np.sin(866*t))

x=np.linspace(0,6,1000)
y1=f1(x)
# def f2(t):
#     return 6*(2*t-1)*np.exp(-2*t)
# y2=f2(x)
plt.plot(x,y1)
# plt.plot(x,y2)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def f1(t):
    return np.exp(-500*t)*(-18*np.cos(866*t)-31.2*np.sin(866*t))

x=np.linspace(0,0.5,1000)
y1=f1(x)
# def f2(t):
#     return 6*(2*t-1)*np.exp(-2*t)
# y2=f2(x)
plt.plot(x,y1)
# plt.plot(x,y2)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def f1(t):
    return np.exp(-500*t)*(-18*np.cos(866*t)-31.2*np.sin(866*t))

x=np.linspace(0,0.05,1000)
y1=f1(x)
# def f2(t):
#     return 6*(2*t-1)*np.exp(-2*t)
# y2=f2(x)
plt.plot(x,y1)
# plt.plot(x,y2)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def f1(t):
    return np.exp(-500*t)*(-18*np.cos(866*t)-31.2*np.sin(866*t))

x=np.linspace(0,0.02,1000)
y1=f1(x)
# def f2(t):
#     return 6*(2*t-1)*np.exp(-2*t)
# y2=f2(x)
plt.plot(x,y1)
# plt.plot(x,y2)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def f1(t):
    return np.exp(-500*t)*(-8*np.cos(866*t)-25.4*np.sin(866*t))

x=np.linspace(0,0.02,1000)
y1=f1(x)
# def f2(t):
#     return 6*(2*t-1)*np.exp(-2*t)
# y2=f2(x)
plt.plot(x,y1)
# plt.plot(x,y2)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def f1(t):
    return np.exp(-500*t)*(-8*np.cos(866*t)-25.4*np.sin(866*t))+2

x=np.linspace(0,0.02,1000)
y1=f1(x)
# def f2(t):
#     return 6*(2*t-1)*np.exp(-2*t)
# y2=f2(x)
plt.plot(x,y1)
# plt.plot(x,y2)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def f1(t):
    return np.exp(-500*t)*(-8*np.cos(866*t)-25.4*np.sin(866*t))+2

x=np.linspace(0,0.02,100)
y1=f1(x)
# def f2(t):
#     return 6*(2*t-1)*np.exp(-2*t)
# y2=f2(x)
plt.plot(x,y1)
# plt.plot(x,y2)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def f1(t):
    return np.exp(-500*t)*(-8*np.cos(866*t)-25.4*np.sin(866*t))+2

x=np.linspace(0,0.02,10)
y1=f1(x)
# def f2(t):
#     return 6*(2*t-1)*np.exp(-2*t)
# y2=f2(x)
plt.plot(x,y1)
# plt.plot(x,y2)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def f1(t):
    return np.exp(-500*t)*(-8*np.cos(866*t)-25.4*np.sin(866*t))+2

x=np.linspace(0,0.02,1000)
y1=f1(x)
# def f2(t):
#     return 6*(2*t-1)*np.exp(-2*t)
# y2=f2(x)
plt.plot(x,y1)
# plt.plot(x,y2)
plt.grid(True)
plt.show()
